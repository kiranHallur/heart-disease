# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
df=pd.read_csv("C:\\Users\\HP\\Desktop\\datas\\heart1.csv")
df.head()
# Out:
#    sbp  tobacco   ldi  adiposity  famhist  typea  obesity  alcohol  age  chd
# 0  160    12.00  5.73      23.11  Present     49    25.30    97.20   52    1
# 1  144     0.01  4.41      28.61   Absent     55    28.87     2.06   63    1
# 2  118     0.08  3.48      32.28  Present     52    29.14     3.81   46    0
# 3  170     7.50  6.41      38.03  Present     51    31.99    24.26   58    1
# 4  134    13.60  3.50      27.78  Present     60    25.99    57.34   49    1

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
df=pd.read_csv("C:\\Users\\HP\\Desktop\\datas\\heart1.csv")
df.head()

history_mapping={'Absent':0,'Present':1}
df["famhist"]=df["famhist"].map(history_mapping)
df.head()
# Out:
#    sbp  tobacco   ldi  adiposity  famhist  typea  obesity  alcohol  age  chd
# 0  160    12.00  5.73      23.11        1     49    25.30    97.20   52    1
# 1  144     0.01  4.41      28.61        0     55    28.87     2.06   63    1
# 2  118     0.08  3.48      32.28        1     52    29.14     3.81   46    0
# 3  170     7.50  6.41      38.03        1     51    31.99    24.26   58    1
# 4  134    13.60  3.50      27.78        1     60    25.99    57.34   49    1

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
df=pd.read_csv("C:\\Users\\HP\\Desktop\\datas\\heart1.csv")
df.head()

history_mapping={'Absent':0,'Present':1}
df["famhist"]=df["famhist"].map(history_mapping)
df.head()

import seaborn as sns
sns.set(style='whitegrid',context='notebook')
cols=['sbp','tobacco','ldi','adiposity','famhist','typea','obesity','alcohol','age','chd']

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
df=pd.read_csv("C:\\Users\\HP\\Desktop\\datas\\heart1.csv")
df.head()

history_mapping={'Absent':0,'Present':1}
df["famhist"]=df["famhist"].map(history_mapping)
df.head()

import seaborn as sns
sns.set(style='whitegrid',context='notebook')
cols=['sbp','tobacco','ldi','adiposity','famhist','typea','obesity','alcohol','age','chd']

import numpy as np
cm=np.corrcoef(df[cols].values.T)
cm
# Out:
# array([[ 1.        ,  0.39481967,  0.95904465,  0.13432444,  0.03253192,
#         -0.46026067,  0.22276857,  0.38787922,  0.5859679 ,  0.73739007],
#        [ 0.39481967,  1.        ,  0.25215509, -0.35816691,  0.57706601,
#          0.17169839, -0.55371957,  0.87037766, -0.27896212,  0.57097147],
#        [ 0.95904465,  0.25215509,  1.        ,  0.23496274,  0.12510678,
#         -0.67656653,  0.33732522,  0.31099447,  0.49311069,  0.51817876],
#        [ 0.13432444, -0.35816691,  0.23496274,  1.        ,  0.13574151,
#         -0.09471625,  0.94332812, -0.65531919,  0.17087971, -0.23272841],
#        [ 0.03253192,  0.57706601,  0.12510678,  0.13574151,  1.        ,
#         -0.20908335, -0.12711684,  0.48278343, -0.7640509 , -0.25      ],
#        [-0.46026067,  0.17169839, -0.67656653, -0.09471625, -0.20908335,
#          1.        , -0.24245925, -0.1584697 , -0.06967833,  0.18294793],
#        [ 0.22276857, -0.55371957,  0.33732522,  0.94332812, -0.12711684,
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
df=pd.read_csv("C:\\Users\\HP\\Desktop\\datas\\heart1.csv")
df.head()

history_mapping={'Absent':0,'Present':1}
df["famhist"]=df["famhist"].map(history_mapping)
df.head()

import seaborn as sns
sns.set(style='whitegrid',context='notebook')
cols=['sbp','tobacco','ldi','adiposity','famhist','alcohol','age','chd']

import numpy as np
cm=np.corrcoef(df[cols].values.T)
cm

f,ax=plt.subplots(figsize=(15,10))
sns.set(font_scale=1.5)
hm=sns.heatmap(cm,
              cbar=True,
              annot=True,
              square=True,
              fmt='.2f',
              annot_kws={'size':15},
              yticklabels=cols,
              xticklabels=cols)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
df=pd.read_csv("C:\\Users\\HP\\Desktop\\datas\\heart1.csv")
df.head()

history_mapping={'Absent':0,'Present':1}
df["famhist"]=df["famhist"].map(history_mapping)
df.head()

import seaborn as sns
sns.set(style='whitegrid',context='notebook')
cols=['sbp','tobacco','adiposity','famhist','typea','alcohol','age','chd']

import numpy as np
cm=np.corrcoef(df[cols].values.T)
cm

f,ax=plt.subplots(figsize=(15,10))
sns.set(font_scale=1.5)
hm=sns.heatmap(cm,
              cbar=True,
              annot=True,
              square=True,
              fmt='.2f',
              annot_kws={'size':15},
              yticklabels=cols,
              xticklabels=cols)
plt.show()

x=df[['sbp','tobacco','ldi','adiposity','famhist','typea','obesity','alcohol','age']].values
y=df[['chd']].values

import sklearn 
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=0)

from sklearn.linear_model import LogisticRegression
model=LogisticRegression()
model.fit(X_train,y_train)
y_pred=model.predict(X_test)
print(y_pred)
print(X_test)
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [18], in <cell line: 40>()
#      38 from sklearn.linear_model import LogisticRegression
#      39 model=LogisticRegression()
# ---> 40 model.fit(X_train,y_train)
#      41 y_pred=model.predict(X_test)
#      42 print(y_pred)
#
# File ~\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1554, in LogisticRegression.fit(self, X, y, sample_weight)
#    1552 classes_ = self.classes_
#    1553 if n_classes < 2:
# -> 1554     raise ValueError(
#    1555         "This solver needs samples of at least 2 classes"
# ...
